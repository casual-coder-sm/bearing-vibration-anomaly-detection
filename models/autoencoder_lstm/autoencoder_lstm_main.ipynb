# %%
import os
from sys import path as sys_path
from pathlib import Path

import numpy as np
np.random.seed(10)
import pandas as pd

import matplotlib.pyplot as plt
#%matplotlib inline

import seaborn as sns
sns.set(color_codes=True)

import tensorflow as tf
# Out:
# 2023-04-22 23:43:11.275140: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
import sys
from sys import path as sys_path

curr_dir = os.getcwd()
#check in the order sub-directory to main-directory
if 'autoencoder_lstm' in  curr_dir:
    os.chdir('..')
if 'models' in curr_dir in curr_dir:
    pass
elif 'bearing-vibration-anomaly-detection' in curr_dir:
    os.chdir('./models')
curr_dir = os.getcwd()
sys_path.insert(0, curr_dir)

# %%
def train_autoencoder_wrapper(time_features_data:pd.DataFrame, cut_off_date_time:str):
    #Step 1 : Re-construct the index columns 'date_time'    
    #print(time_features_data.describe().T)
    #print(time_features_data.columns)
    time_features_data=time_features_data.rename(columns={'filename':'date_time'})
    time_features_data['date_time']=pd.to_datetime(time_features_data['date_time'])   
    
    #Step 2 : Prepare Train, Validation and Test test
    train = time_features_data[time_features_data['date_time'] <= cut_off_date_time]
    test  = time_features_data[time_features_data['date_time'] > cut_off_date_time]
    train = train.set_index('date_time')
    test  = test.set_index('date_time')

    #Step 3 : Prepare Data : Normalize & Reshape
    X_train, X_test = scale_timefeature_data(train, test, True)
    return

# %%
from autoencoder_lstm.Bvad_AutoEncoder import Bvad_AutoEncoder
from autoencoder_lstm.ScalerWrapper import ScalerWrapper
from model_feedinput_pipeline import CODE_ENV, DATASET_ID
from autoencoder_lstm.autoencoder_lstm_generate_features import get_time_features

# %%
def get_dataset_paths(code_env:CODE_ENV)->dict:

    #Step1 : set the pre-defined root folder paths
    if code_env == CODE_ENV.EC2:
        #To access 's3' without any access key embedded folloWSLg dependencies shall be met:
        # 1. Policy for user : Allow-S3-Passrole-to-EC2, AmazonS3FullAccess
        # 2. Role            : S3Admin
        import boto3
        aws_s3 = boto3.resource('s3')
        s3_bucket = aws_s3.Bucket('anomaly-detection-from-bearing-vibration-project-bucket')
        s3_bucket_objects=[]
        for s3_bucket_object in s3_bucket.objects.all():
            s3_bucket_objects.append(s3_bucket_object)
    elif code_env == CODE_ENV.WSL:
        ##################################################################################
        #SET PATH to DATASET in your PC (till but not including folder named '1st')
        #CUSTOMIZE AS per your PC setup
        #curr_dir=os.getcwd()        
        curr_dir = str(Path('/mnt/g/My Drive/CDS/github/CDS/capstone_project/'))
        dataset_root_path =Path('')
        dataset_root_path1 = Path(curr_dir+'/'+'capstone-data/01_PHM-Bearing')
        dataset_root_path2 = Path(curr_dir+'/'+'models/capstone-data/01_PHM-Bearing')
        if dataset_root_path1.is_dir():
            dataset_root_path = dataset_root_path1
        elif dataset_root_path2.is_dir():
            dataset_root_path = dataset_root_path2
        else:
            print('Path ERROR!!!', str(dataset_root_path1), str(dataset_root_path2))
        ##################################################################################
    elif code_env == CODE_ENV.DEV:
        dataset_root_path = Path('/root/datasets/phm-ims-datasets')
        if not dataset_root_path.is_dir():
            print('Check Folder path = ', dataset_root_path.as_posix())
        
    
    #Step2 : collect 3 dataset file details
    if code_env == CODE_ENV.EC2:
        s3_objects_1st_dataset=[]
        s3_objects_2nd_dataset=[]
        s3_objects_3rd_dataset=[]
        paths = []
        for s3_object in s3_bucket_objects:
            path_parts = Path(s3_object.key).parts
            if len(path_parts) == 4 and path_parts[0] == 'data_input' and path_parts[1] == 'IMS':
                paths.append(s3_object)
                if path_parts[2] == '1st_test':
                    s3_objects_1st_dataset.append(s3_object)
                elif path_parts[2] == '2nd_test':
                    s3_objects_2nd_dataset.append(s3_object)
                else:
                    s3_objects_3rd_dataset.append(s3_object)
    elif code_env == CODE_ENV.WSL or code_env == CODE_ENV.DEV:
        data_set1_path = dataset_root_path.as_posix() + '/1st_test'
        data_set2_path = dataset_root_path.as_posix() + '/2nd_test'
        data_set3_path = dataset_root_path.as_posix() + '/3rd_test'
        filelist_1st_dataset = [data_set1_path+'/'+src_path for src_path in sorted(os.listdir(data_set1_path))]
        filelist_2nd_dataset = [data_set2_path+'/'+src_path for src_path in sorted(os.listdir(data_set2_path))]
        filelist_3rd_dataset = [data_set3_path+'/'+src_path for src_path in sorted(os.listdir(data_set3_path))]
    
    #Step3 : Consolidate to structure => Output
    #1st Set has 8 
    col_names_1st = ['b1_ch1', 'b1_ch2', 'b2_ch3', 'b2_ch4', 'b3_ch5', 'b3_ch6', 'b4_ch7', 'b4_ch8']
    #2nd and 3rd has 4
    col_names_2nd_3rd = ['b1_ch1', 'b2_ch2', 'b3_ch3', 'b4_ch4']

    dataset_details = {}
    dataset_details[DATASET_ID.First]  = {'col_names':col_names_1st}
    dataset_details[DATASET_ID.Second] = {'col_names':col_names_2nd_3rd}
    dataset_details[DATASET_ID.Third]  = {'col_names':col_names_2nd_3rd}

    if code_env == CODE_ENV.EC2:
        dataset_details[DATASET_ID.First]['paths']=s3_objects_1st_dataset
        dataset_details[DATASET_ID.Second]['paths']=s3_objects_2nd_dataset
        dataset_details[DATASET_ID.Third]['paths']=s3_objects_3rd_dataset
        #Verify variables
        #print('Number of files in 1st Dataset:', len(dataset_details[DATASET_ID.First]['paths']), 'first file=', dataset_details[DATASET_ID.First]['paths'][0].key)
        #print('Number of files in 2nd Dataset:', len(dataset_details[DATASET_ID.Second]['paths']), 'first file=', dataset_details[DATASET_ID.Second]['paths'][0].key)
        #print('Number of files in 3rd Dataset:', len(dataset_details[DATASET_ID.Third]['paths']), 'first file=', dataset_details[DATASET_ID.Third]['paths'][0].key)

    elif code_env == CODE_ENV.WSL or code_env == CODE_ENV.DEV:
        dataset_details[DATASET_ID.First]['paths']=filelist_1st_dataset
        dataset_details[DATASET_ID.Second]['paths']=filelist_2nd_dataset
        dataset_details[DATASET_ID.Third]['paths']=filelist_3rd_dataset
        #Verify variables
        #print('Number of files in 1st Dataset:', len(dataset_details[DATASET_ID.First]['paths']), 'first file=', dataset_details[DATASET_ID.First]['paths'][0])
        #print('Number of files in 2nd Dataset:', len(dataset_details[DATASET_ID.Second]['paths']), 'first file=', dataset_details[DATASET_ID.Second]['paths'][0])
        #print('Number of files in 3rd Dataset:', len(dataset_details[DATASET_ID.Third]['paths']), 'first file=', dataset_details[DATASET_ID.Third]['paths'][0])
    
    return dataset_details

# %%
#####################################################################################
#***************IMP: Update coding environment********************
#####################################################################################
code_env = CODE_ENV.WSL

#Test Stage 1 : Setup Data Source
dataset_paths = get_dataset_paths(code_env)

# %%
select_columns = [
    ['b1_ch1', 'b2_ch3', 'b3_ch5', 'b4_ch7']
    , ['b1_ch2', 'b2_ch4', 'b3_ch6', 'b4_ch8']
    , ['b1_ch1', 'b2_ch2', 'b3_ch3', 'b4_ch4']
    , ['b1_ch1', 'b2_ch2', 'b3_ch3', 'b4_ch4']
]
time_feature_data_filename = ['timefeatures_1st_1.csv'
                                , 'timefeatures_1st_2.csv'
                                , 'timefeatures_2nd.csv'
                                , 'timefeatures_3rd.csv']
dataset_id_mapping=[
    DATASET_ID.First,
    DATASET_ID.First,
    DATASET_ID.Second,
    DATASET_ID.Third
]
cut_off_date_time =[
    '2003-11-20 23:54:03',
    '2003-11-20 23:54:03',
    '2004-02-15 12:52:39',
    '2004-04-08 23:51:57'
]
scaler_filenames=[
    "scaler_1st_1",
    "scaler_1st_2",
    "scaler_2nd",
    "scaler_3rd"
]

# %%
#Test Stage 2 : Generate the timefeatures
flag_generate_features=True
if flag_generate_features:
    time_feature_data = []
    scalers_data = []
    for i in range(len(select_columns)):
        time_feature_data.append(get_time_features(code_env, dataset_paths, dataset_id_mapping[i], select_columns[i]))
        time_feature_data[i].to_csv(time_feature_data_filename[i])
# Out:
# Processed  0  out of  2156
# Processed  10  out of  2156
# Processed  20  out of  2156
# Processed  30  out of  2156
# Processed  40  out of  2156
# Processed  50  out of  2156
# Processed  60  out of  2156
# Processed  70  out of  2156
# Processed  80  out of  2156
# Processed  90  out of  2156
# Processed  100  out of  2156
# Processed  110  out of  2156
# Processed  120  out of  2156
# Processed  130  out of  2156
# Processed  140  out of  2156
# Processed  150  out of  2156
# Processed  160  out of  2156
# Processed  170  out of  2156
# Processed  180  out of  2156
# Processed  190  out of  2156
# Processed  200  out of  2156
# Processed  210  out of  2156
# Processed  220  out of  2156
# Processed  230  out of  2156
# Processed  240  out of  2156
# Processed  250  out of  2156
# Processed  260  out of  2156
# Processed  270  out of  2156
# Processed  280  out of  2156
# Processed  290  out of  2156
# Processed  300  out of  2156
# Processed  310  out of  2156
# Processed  320  out of  2156
# Processed  330  out of  2156
# Processed  340  out of  2156
# Processed  350  out of  2156
# Processed  360  out of  2156
# Processed  370  out of  2156
# Processed  380  out of  2156
# Processed  390  out of  2156
# Processed  400  out of  2156
# Processed  410  out of  2156
# Processed  420  out of  2156
# Processed  430  out of  2156
# Processed  440  out of  2156
# Processed  450  out of  2156
# Processed  460  out of  2156
# Processed  470  out of  2156
# Processed  480  out of  2156
# Processed  490  out of  2156
# Processed  500  out of  2156
# Processed  510  out of  2156
# Processed  520  out of  2156
# Processed  530  out of  2156
# Processed  540  out of  2156
# Processed  550  out of  2156
# Processed  560  out of  2156
# Processed  570  out of  2156
# Processed  580  out of  2156
# Processed  590  out of  2156
# Processed  600  out of  2156
# Processed  610  out of  2156
# Processed  620  out of  2156
# Processed  630  out of  2156
# Processed  640  out of  2156
# Processed  650  out of  2156
# Processed  660  out of  2156
# Processed  670  out of  2156
# Processed  680  out of  2156
# Processed  690  out of  2156
# Processed  700  out of  2156
# Processed  710  out of  2156
# Processed  720  out of  2156
# Processed  730  out of  2156
# Processed  740  out of  2156
# Processed  750  out of  2156
# Processed  760  out of  2156
# Processed  770  out of  2156
# Processed  780  out of  2156
# Processed  790  out of  2156
# Processed  800  out of  2156
# Processed  810  out of  2156
# Processed  820  out of  2156
# Processed  830  out of  2156
# Processed  840  out of  2156
# Processed  850  out of  2156
# Processed  860  out of  2156
# Processed  870  out of  2156
# Processed  880  out of  2156
# Processed  890  out of  2156
# Processed  900  out of  2156
# Processed  910  out of  2156
# Processed  920  out of  2156
# Processed  930  out of  2156
# Processed  940  out of  2156
# Processed  950  out of  2156
# Processed  960  out of  2156
# Processed  970  out of  2156
# Processed  980  out of  2156
# Processed  990  out of  2156
# Processed  1000  out of  2156
# Processed  1010  out of  2156
# Processed  1020  out of  2156
# Processed  1030  out of  2156
# Processed  1040  out of  2156
# Processed  1050  out of  2156
# Processed  1060  out of  2156
# Processed  1070  out of  2156
# Processed  1080  out of  2156
# Processed  1090  out of  2156
# Processed  1100  out of  2156
# Processed  1110  out of  2156
# Processed  1120  out of  2156
# Processed  1130  out of  2156
# Processed  1140  out of  2156
# Processed  1150  out of  2156
# Processed  1160  out of  2156
# Processed  1170  out of  2156
# Processed  1180  out of  2156
# Processed  1190  out of  2156
# Processed  1200  out of  2156
# Processed  1210  out of  2156
# Processed  1220  out of  2156
# Processed  1230  out of  2156
# Processed  1240  out of  2156
# Processed  1250  out of  2156
# Processed  1260  out of  2156
# Processed  1270  out of  2156
# Processed  1280  out of  2156
# Processed  1290  out of  2156
# Processed  1300  out of  2156
# Processed  1310  out of  2156
# Processed  1320  out of  2156
# Processed  1330  out of  2156
# Processed  1340  out of  2156
# Processed  1350  out of  2156
# Processed  1360  out of  2156
# Processed  1370  out of  2156
# Processed  1380  out of  2156
# Processed  1390  out of  2156
# Processed  1400  out of  2156
# Processed  1410  out of  2156
# Processed  1420  out of  2156
# Processed  1430  out of  2156
# Processed  1440  out of  2156
# Processed  1450  out of  2156
# Processed  1460  out of  2156
# Processed  1470  out of  2156
# Processed  1480  out of  2156
# Processed  1490  out of  2156
# Processed  1500  out of  2156
# Processed  1510  out of  2156
# Processed  1520  out of  2156
# Processed  1530  out of  2156
# Processed  1540  out of  2156
# Processed  1550  out of  2156
# Processed  1560  out of  2156
# Processed  1570  out of  2156
# Processed  1580  out of  2156
# Processed  1590  out of  2156
# Processed  1600  out of  2156
# Processed  1610  out of  2156
# Processed  1620  out of  2156
# Processed  1630  out of  2156
# Processed  1640  out of  2156
# Processed  1650  out of  2156
# Processed  1660  out of  2156
# Processed  1670  out of  2156
# Processed  1680  out of  2156
# Processed  1690  out of  2156
# Processed  1700  out of  2156
# Processed  1710  out of  2156
# Processed  1720  out of  2156
# Processed  1730  out of  2156
# Processed  1740  out of  2156
# Processed  1750  out of  2156
# Processed  1760  out of  2156
# Processed  1770  out of  2156
# Processed  1780  out of  2156
# Processed  1790  out of  2156
# Processed  1800  out of  2156
# Processed  1810  out of  2156
# Processed  1820  out of  2156
# Processed  1830  out of  2156
# Processed  1840  out of  2156
# Processed  1850  out of  2156
# Processed  1860  out of  2156
# Processed  1870  out of  2156
# Processed  1880  out of  2156
# Processed  1890  out of  2156
# Processed  1900  out of  2156
# Processed  1910  out of  2156
# Processed  1920  out of  2156
# Processed  1930  out of  2156
# Processed  1940  out of  2156
# Processed  1950  out of  2156
# Processed  1960  out of  2156
# Processed  1970  out of  2156
# Processed  1980  out of  2156
# Processed  1990  out of  2156
# Processed  2000  out of  2156
# Processed  2010  out of  2156
# Processed  2020  out of  2156
# Processed  2030  out of  2156
# Processed  2040  out of  2156
# Processed  2050  out of  2156
# Processed  2060  out of  2156
# Processed  2070  out of  2156
# Processed  2080  out of  2156
# Processed  2090  out of  2156
# Processed  2100  out of  2156
# Processed  2110  out of  2156
# Processed  2120  out of  2156
# Processed  2130  out of  2156
# Processed  2140  out of  2156
# Processed  2150  out of  2156
# Processed  0  out of  2156
# Processed  10  out of  2156
# Processed  20  out of  2156
# Processed  30  out of  2156
# Processed  40  out of  2156
# Processed  50  out of  2156
# Processed  60  out of  2156
# Processed  70  out of  2156
# Processed  80  out of  2156
# Processed  90  out of  2156
# Processed  100  out of  2156
# Processed  110  out of  2156
# Processed  120  out of  2156
# Processed  130  out of  2156
# Processed  140  out of  2156
# Processed  150  out of  2156
# Processed  160  out of  2156
# Processed  170  out of  2156
# Processed  180  out of  2156
# Processed  190  out of  2156
# Processed  200  out of  2156
# Processed  210  out of  2156
# Processed  220  out of  2156
# Processed  230  out of  2156
# Processed  240  out of  2156
# Processed  250  out of  2156
# Processed  260  out of  2156
# Processed  270  out of  2156
# Processed  280  out of  2156
# Processed  290  out of  2156
# Processed  300  out of  2156
# Processed  310  out of  2156
# Processed  320  out of  2156
# Processed  330  out of  2156
# Processed  340  out of  2156
# Processed  350  out of  2156
# Processed  360  out of  2156
# Processed  370  out of  2156
# Processed  380  out of  2156
# Processed  390  out of  2156
# Processed  400  out of  2156
# Processed  410  out of  2156
# Processed  420  out of  2156
# Processed  430  out of  2156
# Processed  440  out of  2156
# Processed  450  out of  2156
# Processed  460  out of  2156
# Processed  470  out of  2156
# Processed  480  out of  2156
# Processed  490  out of  2156
# Processed  500  out of  2156
# Processed  510  out of  2156
# Processed  520  out of  2156
# Processed  530  out of  2156
# Processed  540  out of  2156
# Processed  550  out of  2156
# Processed  560  out of  2156
# Processed  570  out of  2156
# Processed  580  out of  2156
# Processed  590  out of  2156
# Processed  600  out of  2156
# Processed  610  out of  2156
# Processed  620  out of  2156
# Processed  630  out of  2156
# Processed  640  out of  2156
# Processed  650  out of  2156
# Processed  660  out of  2156
# Processed  670  out of  2156
# Processed  680  out of  2156
# Processed  690  out of  2156
# Processed  700  out of  2156
# Processed  710  out of  2156
# Processed  720  out of  2156
# Processed  730  out of  2156
# Processed  740  out of  2156
# Processed  750  out of  2156
# Processed  760  out of  2156
# Processed  770  out of  2156
# Processed  780  out of  2156
# Processed  790  out of  2156
# Processed  800  out of  2156
# Processed  810  out of  2156
# Processed  820  out of  2156
# Processed  830  out of  2156
# Processed  840  out of  2156
# Processed  850  out of  2156
# Processed  860  out of  2156
# Processed  870  out of  2156
# Processed  880  out of  2156
# Processed  890  out of  2156
# Processed  900  out of  2156
# Processed  910  out of  2156
# Processed  920  out of  2156
# Processed  930  out of  2156
# Processed  940  out of  2156
# Processed  950  out of  2156
# Processed  960  out of  2156
# Processed  970  out of  2156
# Processed  980  out of  2156
# Processed  990  out of  2156
# Processed  1000  out of  2156
# Processed  1010  out of  2156
# Processed  1020  out of  2156
# Processed  1030  out of  2156
# Processed  1040  out of  2156
# Processed  1050  out of  2156
# Processed  1060  out of  2156
# Processed  1070  out of  2156
# Processed  1080  out of  2156
# Processed  1090  out of  2156
# Processed  1100  out of  2156
# Processed  1110  out of  2156
# Processed  1120  out of  2156
# Processed  1130  out of  2156
# Processed  1140  out of  2156
# Processed  1150  out of  2156
# Processed  1160  out of  2156
# Processed  1170  out of  2156
# Processed  1180  out of  2156
# Processed  1190  out of  2156
# Processed  1200  out of  2156
# Processed  1210  out of  2156
# Processed  1220  out of  2156
# Processed  1230  out of  2156
# Processed  1240  out of  2156
# Processed  1250  out of  2156
# Processed  1260  out of  2156
# Processed  1270  out of  2156
# Processed  1280  out of  2156
# Processed  1290  out of  2156
# Processed  1300  out of  2156
# Processed  1310  out of  2156
# Processed  1320  out of  2156
# Processed  1330  out of  2156
# Processed  1340  out of  2156
# Processed  1350  out of  2156
# Processed  1360  out of  2156
# Processed  1370  out of  2156
# Processed  1380  out of  2156
# Processed  1390  out of  2156
# Processed  1400  out of  2156
# Processed  1410  out of  2156
# Processed  1420  out of  2156
# Processed  1430  out of  2156
# Processed  1440  out of  2156
# Processed  1450  out of  2156
# Processed  1460  out of  2156
# Processed  1470  out of  2156
# Processed  1480  out of  2156
# Processed  1490  out of  2156
# Processed  1500  out of  2156
# Processed  1510  out of  2156
# Processed  1520  out of  2156
# Processed  1530  out of  2156
# Processed  1540  out of  2156
# Processed  1550  out of  2156
# Processed  1560  out of  2156
# Processed  1570  out of  2156
# Processed  1580  out of  2156
# Processed  1590  out of  2156
# Processed  1600  out of  2156
# Processed  1610  out of  2156
# Processed  1620  out of  2156
# Processed  1630  out of  2156
# Processed  1640  out of  2156
# Processed  1650  out of  2156
# Processed  1660  out of  2156
# Processed  1670  out of  2156
# Processed  1680  out of  2156
# Processed  1690  out of  2156
# Processed  1700  out of  2156
# Processed  1710  out of  2156
# Processed  1720  out of  2156
# Processed  1730  out of  2156
# Processed  1740  out of  2156
# Processed  1750  out of  2156
# Processed  1760  out of  2156
# Processed  1770  out of  2156
# Processed  1780  out of  2156
# Processed  1790  out of  2156
# Processed  1800  out of  2156
# Processed  1810  out of  2156
# Processed  1820  out of  2156
# Processed  1830  out of  2156
# Processed  1840  out of  2156
# Processed  1850  out of  2156
# Processed  1860  out of  2156
# Processed  1870  out of  2156
# Processed  1880  out of  2156
# Processed  1890  out of  2156
# Processed  1900  out of  2156
# Processed  1910  out of  2156
# Processed  1920  out of  2156
# Processed  1930  out of  2156
# Processed  1940  out of  2156
# Processed  1950  out of  2156
# Processed  1960  out of  2156
# Processed  1970  out of  2156
# Processed  1980  out of  2156
# Processed  1990  out of  2156
# Processed  2000  out of  2156
# Processed  2010  out of  2156
# Processed  2020  out of  2156
# Processed  2030  out of  2156
# Processed  2040  out of  2156
# Processed  2050  out of  2156
# Processed  2060  out of  2156
# Processed  2070  out of  2156
# Processed  2080  out of  2156
# Processed  2090  out of  2156
# Processed  2100  out of  2156
# Processed  2110  out of  2156
# Processed  2120  out of  2156
# Processed  2130  out of  2156
# Processed  2140  out of  2156
# Processed  2150  out of  2156
# Processed  0  out of  984
# Processed  10  out of  984
# Processed  20  out of  984
# Processed  30  out of  984
# Processed  40  out of  984
# Processed  50  out of  984
# Processed  60  out of  984
# Processed  70  out of  984
# Processed  80  out of  984
# Processed  90  out of  984
# Processed  100  out of  984
# Processed  110  out of  984
# Processed  120  out of  984
# Processed  130  out of  984
# Processed  140  out of  984
# Processed  150  out of  984
# Processed  160  out of  984
# Processed  170  out of  984
# Processed  180  out of  984
# Processed  190  out of  984
# Processed  200  out of  984
# Processed  210  out of  984
# Processed  220  out of  984
# Processed  230  out of  984
# Processed  240  out of  984
# Processed  250  out of  984
# Processed  260  out of  984
# Processed  270  out of  984
# Processed  280  out of  984
# Processed  290  out of  984
# Processed  300  out of  984
# Processed  310  out of  984
# Processed  320  out of  984
# Processed  330  out of  984
# Processed  340  out of  984
# Processed  350  out of  984
# Processed  360  out of  984
# Processed  370  out of  984
# Processed  380  out of  984
# Processed  390  out of  984
# Processed  400  out of  984
# Processed  410  out of  984
# Processed  420  out of  984
# Processed  430  out of  984
# Processed  440  out of  984
# Processed  450  out of  984
# Processed  460  out of  984
# Processed  470  out of  984
# Processed  480  out of  984
# Processed  490  out of  984
# Processed  500  out of  984
# Processed  510  out of  984
# Processed  520  out of  984
# Processed  530  out of  984
# Processed  540  out of  984
# Processed  550  out of  984
# Processed  560  out of  984
# Processed  570  out of  984
# Processed  580  out of  984
# Processed  590  out of  984
# Processed  600  out of  984
# Processed  610  out of  984
# Processed  620  out of  984
# Processed  630  out of  984
# Processed  640  out of  984
# Processed  650  out of  984
# Processed  660  out of  984
# Processed  670  out of  984
# Processed  680  out of  984
# Processed  690  out of  984
# Processed  700  out of  984
# Processed  710  out of  984
# Processed  720  out of  984
# Processed  730  out of  984
# Processed  740  out of  984
# Processed  750  out of  984
# Processed  760  out of  984
# Processed  770  out of  984
# Processed  780  out of  984
# Processed  790  out of  984
# Processed  800  out of  984
# Processed  810  out of  984
# Processed  820  out of  984
# Processed  830  out of  984
# Processed  840  out of  984
# Processed  850  out of  984
# Processed  860  out of  984
# Processed  870  out of  984
# Processed  880  out of  984
# Processed  890  out of  984
# Processed  900  out of  984
# Processed  910  out of  984
# Processed  920  out of  984
# Processed  930  out of  984
# Processed  940  out of  984
# Processed  950  out of  984
# Processed  960  out of  984
# Processed  970  out of  984
# Processed  980  out of  984
# Processed  0  out of  6324
# Processed  10  out of  6324
# Processed  20  out of  6324
# Processed  30  out of  6324
# Processed  40  out of  6324
# Processed  50  out of  6324
# Processed  60  out of  6324
# Processed  70  out of  6324
# Processed  80  out of  6324
# Processed  90  out of  6324
# Processed  100  out of  6324
# Processed  110  out of  6324
# Processed  120  out of  6324
# Processed  130  out of  6324
# Processed  140  out of  6324
# Processed  150  out of  6324
# Processed  160  out of  6324
# Processed  170  out of  6324
# Processed  180  out of  6324
# Processed  190  out of  6324
# Processed  200  out of  6324
# Processed  210  out of  6324
# Processed  220  out of  6324
# Processed  230  out of  6324
# Processed  240  out of  6324
# Processed  250  out of  6324
# Processed  260  out of  6324
# Processed  270  out of  6324
# Processed  280  out of  6324
# Processed  290  out of  6324
# Processed  300  out of  6324
# Processed  310  out of  6324
# Processed  320  out of  6324
# Processed  330  out of  6324
# Processed  340  out of  6324
# Processed  350  out of  6324
# Processed  360  out of  6324
# Processed  370  out of  6324
# Processed  380  out of  6324
# Processed  390  out of  6324
# Processed  400  out of  6324
# Processed  410  out of  6324
# Processed  420  out of  6324
# Processed  430  out of  6324
# Processed  440  out of  6324
# Processed  450  out of  6324
# Processed  460  out of  6324
# Processed  470  out of  6324
# Processed  480  out of  6324
# Processed  490  out of  6324
# Processed  500  out of  6324
# Processed  510  out of  6324
# Processed  520  out of  6324
# Processed  530  out of  6324
# Processed  540  out of  6324
# Processed  550  out of  6324
# Processed  560  out of  6324
# Processed  570  out of  6324
# Processed  580  out of  6324
# Processed  590  out of  6324
# Processed  600  out of  6324
# Processed  610  out of  6324
# Processed  620  out of  6324
# Processed  630  out of  6324
# Processed  640  out of  6324
# Processed  650  out of  6324
# Processed  660  out of  6324
# Processed  670  out of  6324
# Processed  680  out of  6324
# Processed  690  out of  6324
# Processed  700  out of  6324
# Processed  710  out of  6324
# Processed  720  out of  6324
# Processed  730  out of  6324
# Processed  740  out of  6324
# Processed  750  out of  6324
# Processed  760  out of  6324
# Processed  770  out of  6324
# Processed  780  out of  6324
# Processed  790  out of  6324
# Processed  800  out of  6324
# Processed  810  out of  6324
# Processed  820  out of  6324
# Processed  830  out of  6324
# Processed  840  out of  6324
# Processed  850  out of  6324
# Processed  860  out of  6324
# Processed  870  out of  6324
# Processed  880  out of  6324
# Processed  890  out of  6324
# Processed  900  out of  6324
# Processed  910  out of  6324
# Processed  920  out of  6324
# Processed  930  out of  6324
# Processed  940  out of  6324
# Processed  950  out of  6324
# Processed  960  out of  6324
# Processed  970  out of  6324
# Processed  980  out of  6324
# Processed  990  out of  6324
# Processed  1000  out of  6324
# Processed  1010  out of  6324
# Processed  1020  out of  6324
# Processed  1030  out of  6324
# Processed  1040  out of  6324
# Processed  1050  out of  6324
# Processed  1060  out of  6324
# Processed  1070  out of  6324
# Processed  1080  out of  6324
# Processed  1090  out of  6324
# Processed  1100  out of  6324
# Processed  1110  out of  6324
# Processed  1120  out of  6324
# Processed  1130  out of  6324
# Processed  1140  out of  6324
# Processed  1150  out of  6324
# Processed  1160  out of  6324
# Processed  1170  out of  6324
# Processed  1180  out of  6324
# Processed  1190  out of  6324
# Processed  1200  out of  6324
# Processed  1210  out of  6324
# Processed  1220  out of  6324
# Processed  1230  out of  6324
# Processed  1240  out of  6324
# Processed  1250  out of  6324
# Processed  1260  out of  6324
# Processed  1270  out of  6324
# Processed  1280  out of  6324
# Processed  1290  out of  6324
# Processed  1300  out of  6324
# Processed  1310  out of  6324
# Processed  1320  out of  6324
# Processed  1330  out of  6324
# Processed  1340  out of  6324
# Processed  1350  out of  6324
# Processed  1360  out of  6324
# Processed  1370  out of  6324
# Processed  1380  out of  6324
# Processed  1390  out of  6324
# Processed  1400  out of  6324
# Processed  1410  out of  6324
# Processed  1420  out of  6324
# Processed  1430  out of  6324
# Processed  1440  out of  6324
# Processed  1450  out of  6324
# Processed  1460  out of  6324
# Processed  1470  out of  6324
# Processed  1480  out of  6324
# Processed  1490  out of  6324
# Processed  1500  out of  6324
# Processed  1510  out of  6324
# Processed  1520  out of  6324
# Processed  1530  out of  6324
# Processed  1540  out of  6324
# Processed  1550  out of  6324
# Processed  1560  out of  6324
# Processed  1570  out of  6324
# Processed  1580  out of  6324
# Processed  1590  out of  6324
# Processed  1600  out of  6324
# Processed  1610  out of  6324
# Processed  1620  out of  6324
# Processed  1630  out of  6324
# Processed  1640  out of  6324
# Processed  1650  out of  6324
# Processed  1660  out of  6324
# Processed  1670  out of  6324
# Processed  1680  out of  6324
# Processed  1690  out of  6324
# Processed  1700  out of  6324
# Processed  1710  out of  6324
# Processed  1720  out of  6324
# Processed  1730  out of  6324
# Processed  1740  out of  6324
# Processed  1750  out of  6324
# Processed  1760  out of  6324
# Processed  1770  out of  6324
# Processed  1780  out of  6324
# Processed  1790  out of  6324
# Processed  1800  out of  6324
# Processed  1810  out of  6324
# Processed  1820  out of  6324
# Processed  1830  out of  6324
# Processed  1840  out of  6324
# Processed  1850  out of  6324
# Processed  1860  out of  6324
# Processed  1870  out of  6324
# Processed  1880  out of  6324
# Processed  1890  out of  6324
# Processed  1900  out of  6324
# Processed  1910  out of  6324
# Processed  1920  out of  6324
# Processed  1930  out of  6324
# Processed  1940  out of  6324
# Processed  1950  out of  6324
# Processed  1960  out of  6324
# Processed  1970  out of  6324
# Processed  1980  out of  6324
# Processed  1990  out of  6324
# Processed  2000  out of  6324
# Processed  2010  out of  6324
# Processed  2020  out of  6324
# Processed  2030  out of  6324
# Processed  2040  out of  6324
# Processed  2050  out of  6324
# Processed  2060  out of  6324
# Processed  2070  out of  6324
# Processed  2080  out of  6324
# Processed  2090  out of  6324
# Processed  2100  out of  6324
# Processed  2110  out of  6324
# Processed  2120  out of  6324
# Processed  2130  out of  6324
# Processed  2140  out of  6324
# Processed  2150  out of  6324
# Processed  2160  out of  6324
# Processed  2170  out of  6324
# Processed  2180  out of  6324
# Processed  2190  out of  6324
# Processed  2200  out of  6324
# Processed  2210  out of  6324
# Processed  2220  out of  6324
# Processed  2230  out of  6324
# Processed  2240  out of  6324
# Processed  2250  out of  6324
# Processed  2260  out of  6324
# Processed  2270  out of  6324
# Processed  2280  out of  6324
# Processed  2290  out of  6324
# Processed  2300  out of  6324
# Processed  2310  out of  6324
# Processed  2320  out of  6324
# Processed  2330  out of  6324
# Processed  2340  out of  6324
# Processed  2350  out of  6324
# Processed  2360  out of  6324
# Processed  2370  out of  6324
# Processed  2380  out of  6324
# Processed  2390  out of  6324
# Processed  2400  out of  6324
# Processed  2410  out of  6324
# Processed  2420  out of  6324
# Processed  2430  out of  6324
# Processed  2440  out of  6324
# Processed  2450  out of  6324
# Processed  2460  out of  6324
# Processed  2470  out of  6324
# Processed  2480  out of  6324
# Processed  2490  out of  6324
# Processed  2500  out of  6324
# Processed  2510  out of  6324
# Processed  2520  out of  6324
# Processed  2530  out of  6324
# Processed  2540  out of  6324
# Processed  2550  out of  6324
# Processed  2560  out of  6324
# Processed  2570  out of  6324
# Processed  2580  out of  6324
# Processed  2590  out of  6324
# Processed  2600  out of  6324
# Processed  2610  out of  6324
# Processed  2620  out of  6324
# Processed  2630  out of  6324
# Processed  2640  out of  6324
# Processed  2650  out of  6324
# Processed  2660  out of  6324
# Processed  2670  out of  6324
# Processed  2680  out of  6324
# Processed  2690  out of  6324
# Processed  2700  out of  6324
# Processed  2710  out of  6324
# Processed  2720  out of  6324
# Processed  2730  out of  6324
# Processed  2740  out of  6324
# Processed  2750  out of  6324
# Processed  2760  out of  6324
# Processed  2770  out of  6324
# Processed  2780  out of  6324
# Processed  2790  out of  6324
# Processed  2800  out of  6324
# Processed  2810  out of  6324
# Processed  2820  out of  6324
# Processed  2830  out of  6324
# Processed  2840  out of  6324
# Processed  2850  out of  6324
# Processed  2860  out of  6324
# Processed  2870  out of  6324
# Processed  2880  out of  6324
# Processed  2890  out of  6324
# Processed  2900  out of  6324
# Processed  2910  out of  6324
# Processed  2920  out of  6324
# Processed  2930  out of  6324
# Processed  2940  out of  6324
# Processed  2950  out of  6324
# Processed  2960  out of  6324
# Processed  2970  out of  6324
# Processed  2980  out of  6324
# Processed  2990  out of  6324
# Processed  3000  out of  6324
# Processed  3010  out of  6324
# Processed  3020  out of  6324
# Processed  3030  out of  6324
# Processed  3040  out of  6324
# Processed  3050  out of  6324
# Processed  3060  out of  6324
# Processed  3070  out of  6324
# Processed  3080  out of  6324
# Processed  3090  out of  6324
# Processed  3100  out of  6324
# Processed  3110  out of  6324
# Processed  3120  out of  6324
# Processed  3130  out of  6324
# Processed  3140  out of  6324
# Processed  3150  out of  6324
# Processed  3160  out of  6324
# Processed  3170  out of  6324
# Processed  3180  out of  6324
# Processed  3190  out of  6324
# Processed  3200  out of  6324
# Processed  3210  out of  6324
# Processed  3220  out of  6324
# Processed  3230  out of  6324
# Processed  3240  out of  6324
# Processed  3250  out of  6324
# Processed  3260  out of  6324
# Processed  3270  out of  6324
# Processed  3280  out of  6324
# Processed  3290  out of  6324
# Processed  3300  out of  6324
# Processed  3310  out of  6324
# Processed  3320  out of  6324
# Processed  3330  out of  6324
# Processed  3340  out of  6324
# Processed  3350  out of  6324
# Processed  3360  out of  6324
# Processed  3370  out of  6324
# Processed  3380  out of  6324
# Processed  3390  out of  6324
# Processed  3400  out of  6324
# Processed  3410  out of  6324
# Processed  3420  out of  6324
# Processed  3430  out of  6324
# Processed  3440  out of  6324
# Processed  3450  out of  6324
# Processed  3460  out of  6324
# Processed  3470  out of  6324
# Processed  3480  out of  6324
# Processed  3490  out of  6324
# Processed  3500  out of  6324
# Processed  3510  out of  6324
# Processed  3520  out of  6324
# Processed  3530  out of  6324
# Processed  3540  out of  6324
# Processed  3550  out of  6324
# Processed  3560  out of  6324
# Processed  3570  out of  6324
# Processed  3580  out of  6324
# Processed  3590  out of  6324
# Processed  3600  out of  6324
# Processed  3610  out of  6324
# Processed  3620  out of  6324
# Processed  3630  out of  6324
# Processed  3640  out of  6324
# Processed  3650  out of  6324
# Processed  3660  out of  6324
# Processed  3670  out of  6324
# Processed  3680  out of  6324
# Processed  3690  out of  6324
# Processed  3700  out of  6324
# Processed  3710  out of  6324
# Processed  3720  out of  6324
# Processed  3730  out of  6324
# Processed  3740  out of  6324
# Processed  3750  out of  6324
# Processed  3760  out of  6324
# Processed  3770  out of  6324
# Processed  3780  out of  6324
# Processed  3790  out of  6324
# Processed  3800  out of  6324
# Processed  3810  out of  6324
# Processed  3820  out of  6324
# Processed  3830  out of  6324
# Processed  3840  out of  6324
# Processed  3850  out of  6324
# Processed  3860  out of  6324
# Processed  3870  out of  6324
# Processed  3880  out of  6324
# Processed  3890  out of  6324
# Processed  3900  out of  6324
# Processed  3910  out of  6324
# Processed  3920  out of  6324
# Processed  3930  out of  6324
# Processed  3940  out of  6324
# Processed  3950  out of  6324
# Processed  3960  out of  6324
# Processed  3970  out of  6324
# Processed  3980  out of  6324
# Processed  3990  out of  6324
# Processed  4000  out of  6324
# Processed  4010  out of  6324
# Processed  4020  out of  6324
# Processed  4030  out of  6324
# Processed  4040  out of  6324
# Processed  4050  out of  6324
# Processed  4060  out of  6324
# Processed  4070  out of  6324
# Processed  4080  out of  6324
# Processed  4090  out of  6324
# Processed  4100  out of  6324
# Processed  4110  out of  6324
# Processed  4120  out of  6324
# Processed  4130  out of  6324
# Processed  4140  out of  6324
# Processed  4150  out of  6324
# Processed  4160  out of  6324
# Processed  4170  out of  6324
# Processed  4180  out of  6324
# Processed  4190  out of  6324
# Processed  4200  out of  6324
# Processed  4210  out of  6324
# Processed  4220  out of  6324
# Processed  4230  out of  6324
# Processed  4240  out of  6324
# Processed  4250  out of  6324
# Processed  4260  out of  6324
# Processed  4270  out of  6324
# Processed  4280  out of  6324
# Processed  4290  out of  6324
# Processed  4300  out of  6324
# Processed  4310  out of  6324
# Processed  4320  out of  6324
# Processed  4330  out of  6324
# Processed  4340  out of  6324
# Processed  4350  out of  6324
# Processed  4360  out of  6324
# Processed  4370  out of  6324
# Processed  4380  out of  6324
# Processed  4390  out of  6324
# Processed  4400  out of  6324
# Processed  4410  out of  6324
# Processed  4420  out of  6324
# Processed  4430  out of  6324
# Processed  4440  out of  6324
# Processed  4450  out of  6324
# Processed  4460  out of  6324
# Processed  4470  out of  6324
# Processed  4480  out of  6324
# Processed  4490  out of  6324
# Processed  4500  out of  6324
# Processed  4510  out of  6324
# Processed  4520  out of  6324
# Processed  4530  out of  6324
# Processed  4540  out of  6324
# Processed  4550  out of  6324
# Processed  4560  out of  6324
# Processed  4570  out of  6324
# Processed  4580  out of  6324
# Processed  4590  out of  6324
# Processed  4600  out of  6324
# Processed  4610  out of  6324
# Processed  4620  out of  6324
# Processed  4630  out of  6324
# Processed  4640  out of  6324
# Processed  4650  out of  6324
# Processed  4660  out of  6324
# Processed  4670  out of  6324
# Processed  4680  out of  6324
# Processed  4690  out of  6324
# Processed  4700  out of  6324
# Processed  4710  out of  6324
# Processed  4720  out of  6324
# Processed  4730  out of  6324
# Processed  4740  out of  6324
# Processed  4750  out of  6324
# Processed  4760  out of  6324
# Processed  4770  out of  6324
# Processed  4780  out of  6324
# Processed  4790  out of  6324
# Processed  4800  out of  6324
# Processed  4810  out of  6324
# Processed  4820  out of  6324
# Processed  4830  out of  6324
# Processed  4840  out of  6324
# Processed  4850  out of  6324
# Processed  4860  out of  6324
# Processed  4870  out of  6324
# Processed  4880  out of  6324
# Processed  4890  out of  6324
# Processed  4900  out of  6324
# Processed  4910  out of  6324
# Processed  4920  out of  6324
# Processed  4930  out of  6324
# Processed  4940  out of  6324
# Processed  4950  out of  6324
# Processed  4960  out of  6324
# Processed  4970  out of  6324
# Processed  4980  out of  6324
# Processed  4990  out of  6324
# Processed  5000  out of  6324
# Processed  5010  out of  6324
# Processed  5020  out of  6324
# Processed  5030  out of  6324
# Processed  5040  out of  6324
# Processed  5050  out of  6324
# Processed  5060  out of  6324
# Processed  5070  out of  6324
# Processed  5080  out of  6324
# Processed  5090  out of  6324
# Processed  5100  out of  6324
# Processed  5110  out of  6324
# Processed  5120  out of  6324
# Processed  5130  out of  6324
# Processed  5140  out of  6324
# Processed  5150  out of  6324
# Processed  5160  out of  6324
# Processed  5170  out of  6324
# Processed  5180  out of  6324
# Processed  5190  out of  6324
# Processed  5200  out of  6324
# Processed  5210  out of  6324
# Processed  5220  out of  6324
# Processed  5230  out of  6324
# Processed  5240  out of  6324
# Processed  5250  out of  6324
# Processed  5260  out of  6324
# Processed  5270  out of  6324
# Processed  5280  out of  6324
# Processed  5290  out of  6324
# Processed  5300  out of  6324
# Processed  5310  out of  6324
# Processed  5320  out of  6324
# Processed  5330  out of  6324
# Processed  5340  out of  6324
# Processed  5350  out of  6324
# Processed  5360  out of  6324
# Processed  5370  out of  6324
# Processed  5380  out of  6324
# Processed  5390  out of  6324
# Processed  5400  out of  6324
# Processed  5410  out of  6324
# Processed  5420  out of  6324
# Processed  5430  out of  6324
# Processed  5440  out of  6324
# Processed  5450  out of  6324
# Processed  5460  out of  6324
# Processed  5470  out of  6324
# Processed  5480  out of  6324
# Processed  5490  out of  6324
# Processed  5500  out of  6324
# Processed  5510  out of  6324
# Processed  5520  out of  6324
# Processed  5530  out of  6324
# Processed  5540  out of  6324
# Processed  5550  out of  6324
# Processed  5560  out of  6324
# Processed  5570  out of  6324
# Processed  5580  out of  6324
# Processed  5590  out of  6324
# Processed  5600  out of  6324
# Processed  5610  out of  6324
# Processed  5620  out of  6324
# Processed  5630  out of  6324
# Processed  5640  out of  6324
# Processed  5650  out of  6324
# Processed  5660  out of  6324
# Processed  5670  out of  6324
# Processed  5680  out of  6324
# Processed  5690  out of  6324
# Processed  5700  out of  6324
# Processed  5710  out of  6324
# Processed  5720  out of  6324
# Processed  5730  out of  6324
# Processed  5740  out of  6324
# Processed  5750  out of  6324
# Processed  5760  out of  6324
# Processed  5770  out of  6324
# Processed  5780  out of  6324
# Processed  5790  out of  6324
# Processed  5800  out of  6324
# Processed  5810  out of  6324
# Processed  5820  out of  6324
# Processed  5830  out of  6324
# Processed  5840  out of  6324
# Processed  5850  out of  6324
# Processed  5860  out of  6324
# Processed  5870  out of  6324
# Processed  5880  out of  6324
# Processed  5890  out of  6324
# Processed  5900  out of  6324
# Processed  5910  out of  6324
# Processed  5920  out of  6324
# Processed  5930  out of  6324
# Processed  5940  out of  6324
# Processed  5950  out of  6324
# Processed  5960  out of  6324
# Processed  5970  out of  6324
# Processed  5980  out of  6324
# Processed  5990  out of  6324
# Processed  6000  out of  6324
# Processed  6010  out of  6324
# Processed  6020  out of  6324
# Processed  6030  out of  6324
# Processed  6040  out of  6324
# Processed  6050  out of  6324
# Processed  6060  out of  6324
# Processed  6070  out of  6324
# Processed  6080  out of  6324
# Processed  6090  out of  6324
# Processed  6100  out of  6324
# Processed  6110  out of  6324
# Processed  6120  out of  6324
# Processed  6130  out of  6324
# Processed  6140  out of  6324
# Processed  6150  out of  6324
# Processed  6160  out of  6324
# Processed  6170  out of  6324
# Processed  6180  out of  6324
# Processed  6190  out of  6324
# Processed  6200  out of  6324
# Processed  6210  out of  6324
# Processed  6220  out of  6324
# Processed  6230  out of  6324
# Processed  6240  out of  6324
# Processed  6250  out of  6324
# Processed  6260  out of  6324
# Processed  6270  out of  6324
# Processed  6280  out of  6324
# Processed  6290  out of  6324
# Processed  6300  out of  6324
# Processed  6310  out of  6324
# Processed  6320  out of  6324

# %%
#Test Stage 3 : Normalize
flag_normalize_features=True
if flag_normalize_features:
    for tf_file_indx in range(len(scaler_filenames)):
        df_features = pd.read_csv(time_feature_data_filename[tf_file_indx])
        train = df_features[df_features['filename']<=cut_off_date_time[tf_file_indx]]
        test  = df_features[df_features['filename']>cut_off_date_time[tf_file_indx]]
        train = train.set_index('filename')
        test  = test.set_index('filename')
        
        scaler = ScalerWrapper()
        scaler.fit_transform(train)
        scaler.transform(test)
        scaler.save_scaler(scaler_filenames[tf_file_indx])

# %%
#Test Stage 4 : Train a model based on selected Dataset and validate Dataset
flag_train_features=False
if flag_train_features:
    tf_file_indx=2
    df_features = pd.read_csv(time_feature_data_filename[tf_file_indx])

    train = df_features[df_features['filename']<=cut_off_date_time[tf_file_indx]]
    test  = df_features[df_features['filename']>cut_off_date_time[tf_file_indx]]
    train = train.set_index('filename')
    test  = test.set_index('filename')
    
    scaler = ScalerWrapper()
    scaler.load_scaler(scaler_filenames[tf_file_indx])
    X_scaled_train, X_scaled_test = scaler.transform(X_train=train, X_test=test)

    print(X_scaled_train.shape, X_scaled_test.shape)
    auto_encoder = Bvad_AutoEncoder(train=X_scaled_train, test=X_scaled_test, scaler=scaler)
    auto_encoder.prepare_lstm_input()
    model, history = auto_encoder.train_autoencoder_model()

    auto_encoder.pred_autoencoder()
    
    #save the model
    model.save('../bvad_ae_lstm')

    history, X_train_pred, threshold, train_scored = auto_encoder.get_training_result()
    # plot the training losses
    fig, ax = plt.subplots(figsize=(14, 6), dpi=80)
    ax.plot(history['loss'], 'b', label='Train', linewidth=2)
    ax.plot(history['val_loss'], 'r', label='Validation', linewidth=2)
    ax.set_title('Model loss', fontsize=16)
    ax.set_ylabel('Loss (mae)')
    ax.set_xlabel('Epoch')
    ax.legend(loc='upper right')
    plt.show()

# %%
#Test Stage 5 :  Predict based on previously trained model and scaler fittened on non-anomaly dataset
flag_test_features=True
if flag_test_features:
    tf_file_indx=1
    df_features = pd.read_csv(time_feature_data_filename[tf_file_indx])
    df_features = df_features.set_index('filename')

    restored_model = tf.keras.models.load_model('../bvad_ae_lstm')

    scaler = ScalerWrapper()
    scaler.load_scaler(scaler_filenames[tf_file_indx])
    _, X_scaled_test = scaler.transform(df_features)

    auto_encoder = Bvad_AutoEncoder(test=df_features, scaler=scaler, model=restored_model)
    auto_encoder.pred_autoencoder(threshold=1.77)


    X_test_pred, _, test_scored = auto_encoder.get_test_result()

    # plot bearing failure time plot
    test_scored.plot(logy=True,  figsize=(8,4), ylim=[1e-2,1e2], color=['blue','red'])
    plt.show()

exit(0)
